# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import ImageFolder
import matplotlib.pyplot as plt
from data_preprocessing import filter_by_num_images
from Models import Basic_CNN_Model

# %%
batch_size = 5
seq = transforms.Compose([transforms.Resize((256, 512)), transforms.ToTensor()])
dataset = ImageFolder('./Data/', seq)
loader = DataLoader(dataset, batch_size, shuffle=False)
for images, data in loader:
    # f, axarr = plt.subplots(1,batch_size)
    # for i in range(batch_size):
        # axarr[0, i].imshow(images[i].permute(1,2,0).numpy())
    plt.imshow(images[0].permute(1,2,0).numpy())
    print(images[0].shape)
    break
# Out:
# torch.Size([3, 256, 512])

# %%
# test_model = Basic_CNN_Model((256, 612), )
